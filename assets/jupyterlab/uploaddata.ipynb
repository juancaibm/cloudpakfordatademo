# %%
import pandas as pd

df_data_1 = pd.read_csv('/project_data/data_asset/Shift.csv')
df_data_1.head()
# Out:
#                          id    department     day  start time  end time  \
# 0      Emergency-Monday-2-8     Emergency  Monday           2         8
# 1     Emergency-Monday-8-12     Emergency  Monday           8        12
# 2    Emergency-Monday-12-18     Emergency  Monday          12        18
# 3     Emergency-Monday-18-2     Emergency  Monday          18         2
# 4  Consultation-Monday-8-12  Consultation  Monday           8        12
#
#    min req  max req         requested skills  duration  day index  \
# 0        2        5  Anaesthesiology,Cardiac         6          1
# 1        3        7  Anaesthesiology,Cardiac         4          1
# 2        1        5  Anaesthesiology,Cardiac         6          1
# 3        2        7  Anaesthesiology,Cardiac         8          1
# 4        6       13  Child Health, Aged Care         4          1
#
#    start hour in week  end hour in week     Week start      Start date  \
# ...
